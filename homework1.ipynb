# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
# %matplotlib inline

# %%
x=2*np.pi*np.linspace(-np.pi,np.pi, 111)
y1=np.sin(x)
y2=np.sin(2*x)

# %%
plt.plot(x,y1,'b');
plt.plot(x,y2,'g');
plt.plot(x,y1+y2,'r');
plt.show()
